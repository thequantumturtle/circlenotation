# %%
import numpy as np
import matplotlib.pyplot as plt
import pylab as pl
from IPython.display import HTML
from matplotlib.animation import FuncAnimation 
from math import pi

# %%
r1 = .707
r2 = .2

theta1 = pi/2
theta2 = pi

beta = np.linspace(0.0 ,1,100)
    
theta = np.linspace(theta1, theta2, 200)
radius = np.linspace(r1, r2, 200)

fig = plt.figure(figsize=(6,6))
ax = plt.subplot(111, polar=True)
test = theta1 
# line, = ax.plot([],[])
theta = [0, test]
r = [0, 1]
line, = ax.plot(theta, r, color='blue')
circle = pl.Circle((0, 0), r1, transform=ax.transData._b, color="red", alpha=0.6)
ax.add_artist(circle)



ani = FuncAnimation(fig, update, frames=beta, blit=True)
HTML(ani.to_html5_video())
# Out:
# <img src="data:image/png;base64,..." width="432">
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-3be73766875e> in <module>
#      23
#      24 ani = FuncAnimation(fig, update, frames=beta, blit=True)
# ---> 25 HTML(ani.to_html5_video())
#
# ~/.virtualenvs/CircleNotation-cPkOILQA/lib/python3.6/site-packages/matplotlib/animation.py in to_html5_video(self, embed_limit)
#    1328                                 bitrate=rcParams['animation.bitrate'],
#    1329                                 fps=1000. / self._interval)
# -> 1330                 self.save(str(path), writer=writer)
#    1331                 # Now open and base64 encode.
#    1332                 vid64 = base64.encodebytes(path.read_bytes())
#
# ...

# %%
def update_circle(step):
    # radius of magnitude
    r = (r2-r1)*step + r1 
    circle.radius = r
    # angle of phase represented by line
    theta = (theta2-theta1)*step + theta1
    line.set_xdata([0, theta])
    line.set_ydata([0,1])

    return line,

# %%
r1 = 0
r2 = .707
theta1 = 0 
theta2 = pi
steps = np.linspace(0.0 ,1,25)

# %%
fig = plt.figure(figsize=(6,6))
ax = plt.subplot(111, polar=True)
line, = ax.plot([0,theta1], [0,1], color='blue')
circle = pl.Circle((0, 0), r1, transform=ax.transData._b, color="red", alpha=0.6)
ax.add_artist(circle)
# Out:
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">

# %%
ani = FuncAnimation(fig, update_circle, frames=steps, blit=True)
HTML(ani.to_html5_video())
# Out:
# <video width="432" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
import matplotlib
# matplotlib.use('Qt5Agg') #use Qt5 as backend, comment this line for default backend

from matplotlib import pyplot as plt
from matplotlib import animation

fig = plt.figure()

ax = plt.axes(xlim=(0, 2), ylim=(0, 100))

N = 4
lines = [plt.plot([], [])[0] for _ in range(N)] #lines to animate

rectangles = plt.bar([0.5,1,1.5],[50,40,90],width=0.1) #rectangles to animate

patches = lines + list(rectangles) #things to animate

def init():
    #init lines
    for line in lines:
        line.set_data([], [])

    #init rectangles
    for rectangle in rectangles:
        rectangle.set_height(0)

    return patches #return everything that must be updated

def animate(i):
    #animate lines
    for j,line in enumerate(lines):
        line.set_data([0, 2], [10 * j,i])

    #animate rectangles
    for j,rectangle in enumerate(rectangles):
        rectangle.set_height(i/(j+1))

    return patches #return everything that must be updated

anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=100, interval=20, blit=True)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">
# Traceback (most recent call last):
#   File "/home/djustice/.virtualenvs/CircleNotation-cPkOILQA/lib/python3.6/site-packages/matplotlib/cbook/__init__.py", line 216, in process
#     func(*args, **kwargs)
#   File "/home/djustice/.virtualenvs/CircleNotation-cPkOILQA/lib/python3.6/site-packages/matplotlib/animation.py", line 1465, in _stop
#     self.event_source.remove_callback(self._loop_delay)
# AttributeError: 'NoneType' object has no attribute 'remove_callback'

# %%
HTML(anim.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
sv1 = [1.0+0.j, 0.+0.j, 0.+0.j, 0+0.j]
sv2 = [0.70710678+0.j, 0.+0.j, 0.+0.j, 0.70710678+0.j]
sv3 = [ 0.70710678+0.j,  0.        +0.j,  0.        +0.j, -0.70710678+0.j]

# %%
len(sv1)
# Out:
# 4

# %%
def update_circle2(step):
    for qstate1, qstate2 in zip(sv1, sv2):
        r1 = np.absolute(qstate1)
        r2 = np.absolute(qstate2)
    
    # radius of magnitude
    r = (r2-r1)*step + r1 
    circle.radius = r
    # angle of phase represented by line
    theta = (theta2-theta1)*step + theta1
    line.set_xdata([0, theta])
    line.set_ydata([0,1])

    return line,

# %%
state_vectors = [sv1, sv2]

r1 = .707
r2 = .2

theta1 = pi/2
theta2 = pi

beta = np.linspace(0.0 ,1,100)
    
theta = np.linspace(theta1, theta2, 200)
radius = np.linspace(r1, r2, 200)

fig = plt.figure(figsize=(6,6))
ax = plt.subplot(111, polar=True)
test = theta1 
# line, = ax.plot([],[])
theta = [0, test]
r = [0, 1]
line, = ax.plot(theta, r, color='blue')
circle = pl.Circle((0, 0), r1, transform=ax.transData._b, color="red", alpha=0.6)
ax.add_artist(circle)



ani = FuncAnimation(fig, update, frames=beta, blit=True)
HTML(ani.to_html5_video())
# Out:
# <img src="data:image/png;base64,..." width="432">
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-52acb7fd25f9> in <module>
#      25
#      26 ani = FuncAnimation(fig, update, frames=beta, blit=True)
# ---> 27 HTML(ani.to_html5_video())
#
# ~/.virtualenvs/CircleNotation-cPkOILQA/lib/python3.6/site-packages/matplotlib/animation.py in to_html5_video(self, embed_limit)
#    1328                                 bitrate=rcParams['animation.bitrate'],
#    1329                                 fps=1000. / self._interval)
# -> 1330                 self.save(str(path), writer=writer)
#    1331                 # Now open and base64 encode.
#    1332                 vid64 = base64.encodebytes(path.read_bytes())
#
# ...

# %%
fig = plt.figure(constrained_layout=True)

import matplotlib.gridspec as gridspec
# Out:
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">

# %%
gs0 = gridspec.GridSpec(1, 2, figure=fig)

# %%
def example_plot(ax):
    ax.plot([1, 2])
    ax.set_xlabel('x-label', fontsize=12)
    ax.set_ylabel('y-label', fontsize=12)
    ax.set_title('Title', fontsize=14)
    
def example_circle_plot(ax, radius=0,theta=pi/2 ):
    line, = ax.plot([0, theta], [0,1], color='blue')
    circle = pl.Circle((0, 0), radius, transform=ax.transData._b, color="red", alpha=0.6)
    ax.add_artist(circle)

# %%
fig = plt.figure()

    
gs0 = gridspec.GridSpec(1, 1, figure=fig)   
gs1 = gridspec.GridSpecFromSubplotSpec(1, 4, subplot_spec=gs0[0])
for n in range(len(sv1)):
    ax = fig.add_subplot(gs1[n], polar=True)
    example_circle_plot(ax, radius=np.absolute(sv1[n]))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">

# %%
# %matplotlib inline

# %%
fig = plt.figure(constrained_layout=True)

import matplotlib.gridspec as gridspec

# %%
gs0 = gridspec.GridSpec(1, 2, figure=fig)

# %%
gs1 = gridspec.GridSpecFromSubplotSpec(3, 1, subplot_spec=gs0[0])
for n in range(3):
    ax = fig.add_subplot(gs1[n])
    example_plot(ax)

# %%
gs2 = gridspec.GridSpecFromSubplotSpec(2, 1, subplot_spec=gs0[1])
for n in range(2):
    ax = fig.add_subplot(gs2[n])
    example_plot(ax)

# %%
# %matplotlib inline
plt.show()

# %%
fig = plt.figure(constrained_layout=True)

import matplotlib.gridspec as gridspec

gs0 = gridspec.GridSpec(1, 2, figure=fig)

gs1 = gridspec.GridSpecFromSubplotSpec(3, 1, subplot_spec=gs0[0])
for n in range(3):
    ax = fig.add_subplot(gs1[n])
    example_plot(ax)


gs2 = gridspec.GridSpecFromSubplotSpec(2, 1, subplot_spec=gs0[1])
for n in range(2):
    ax = fig.add_subplot(gs2[n])
    example_plot(ax)

plt.show()

# %%
plt.show()

# %%
plt.show()

# %%
fig = plt.figure(constrained_layout=True)

import matplotlib.gridspec as gridspec

gs0 = gridspec.GridSpec(1, 2, figure=fig)

gs1 = gridspec.GridSpecFromSubplotSpec(3, 1, subplot_spec=gs0[0])
for n in range(3):
    ax = fig.add_subplot(gs1[n])
    example_plot(ax)


gs2 = gridspec.GridSpecFromSubplotSpec(2, 1, subplot_spec=gs0[1])
for n in range(2):
    ax = fig.add_subplot(gs2[n])
    example_plot(ax)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import animation

x1 = np.random.normal(-2.5, 1, 10000)
x2 = np.random.gamma(2, 1.5, 10000)
x3 = np.random.exponential(2, 10000)+7
x4 = np.random.uniform(14,20, 10000)
xrand = np.random.random(size = 10000)
x = [x1, x2, x3, x4]

bins1 = np.arange(-7.5, 2.5, 0.2)
bins2 = np.arange(0, 10, 0.2)
bins3 = np.arange(7, 17, 0.2)
bins4 = np.arange(12, 22, 0.2)
bins = [bins1, bins2, bins3, bins4]

axis1 = [-7.5, 2.5, 0, 0.6]
axis2 = [0, 10, 0, 0.6]
axis3 = [7, 17, 0, 0.6]
axis4 = [12, 22, 0, 0.6]
axis  = [axis1, axis2, axis3, axis4]


fig, ((GS1,GS2),(GS3, GS4)) = plt.subplots(2, 2, sharey = True)
GS = [GS1, GS2, GS3, GS4]


def update(curr):
    if curr == 500:
        a.event_source.stop()
    for i in range(0, len(GS)):
        GS[i].clear()
        GS[i].hist(x[i][:curr], bins = bins[i], density = True)
        GS[i].axis(axis[i])
        GS[i].set_title('Sampling random distribution')
        GS[i].set_ylabel('Frequency')
        GS[i].set_xlabel('Value')
        GS[i].annotate('n = {}'.format(curr), [3,27])


# plt.tight_layout()
fig = plt.gcf()    
a = animation.FuncAnimation(fig, update, interval = 10)

plt.show()
# Out:
# /home/djustice/.virtualenvs/CircleNotation-cPkOILQA/lib/python3.6/site-packages/numpy/lib/histograms.py:908: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges

# %%
import matplotlib.animation as animation
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib notebook

x1 = np.random.normal(-2.5, 1, 10000)
x2 = np.random.gamma(2, 1.5, 10000)
x3 = np.random.exponential(2, 10000)+7
x4 = np.random.uniform(14,20, 10000)

x = [x1, x2, x3, x4]

bins1 = np.arange(-7.5, 2.5, 0.2)
bins2 = np.arange(0, 10, 0.2)
bins3 = np.arange(7, 17, 0.2)
bins4 = np.arange(12, 22, 0.2)
bins = [bins1, bins2, bins3, bins4]

axis1 = [-7.5, 2.5, 0, 0.6]
axis2 = [0, 10, 0, 0.6]
axis3 = [7, 17, 0, 0.6]
axis4 = [12, 22, 0, 0.6]
axis = [axis1, axis2, axis3, axis4]

import matplotlib.gridspec as gridspec

gspec = gridspec.GridSpec(4, 4)
plt.figure()
ax1 = plt.subplot(gspec[0:2, 0:2])
ax2 = plt.subplot(gspec[0:2, 2:])
ax3 = plt.subplot(gspec[2:, 2:])
ax4 = plt.subplot(gspec[2:, 0:2])
ax = [ax1, ax2, ax3, ax4] 
for a in ax:
    a.spines['right'].set_visible(False)
    a.spines['top'].set_visible(False)
gspec.update(wspace = .6, hspace = .6)

def update(curr):
    if curr == 500:
        a.event_source.stop()
    for i in range(len(ax)):
        ax[i].cla()
        ax[i].hist(x[i][:curr], normed = True, bins = bins[i])
        ax[i].axis(axis[i])
        ax[i].set_title('n={}'.format(curr))
        ax[i].set_ylabel('Normed Frequency')
#     plt.tight_layout()

fig = plt.gcf()    
a = animation.FuncAnimation(fig, update, interval = 10)
# plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">
# Traceback (most recent call last):
#   File "/home/djustice/.virtualenvs/CircleNotation-cPkOILQA/lib/python3.6/site-packages/matplotlib/cbook/__init__.py", line 216, in process
#     func(*args, **kwargs)
#   File "/home/djustice/.virtualenvs/CircleNotation-cPkOILQA/lib/python3.6/site-packages/matplotlib/animation.py", line 1465, in _stop
#     self.event_source.remove_callback(self._loop_delay)
# AttributeError: 'NoneType' object has no attribute 'remove_callback'

# %%
x1 = np.random.normal(-2.5, 1, 10000)

# %%
non_flat = [ [1,2,3], [4,5,6], [7,8] ]
[y for y in x for x in non_flat]
# Out:
# [array([-3.54901149, -1.22330961, -1.95594672, ..., -2.21927882,
#         -1.0364917 , -2.69113275]),
#  array([-3.54901149, -1.22330961, -1.95594672, ..., -2.21927882,
#         -1.0364917 , -2.69113275]),
#  array([-3.54901149, -1.22330961, -1.95594672, ..., -2.21927882,
#         -1.0364917 , -2.69113275]),
#  array([1.71266459, 7.92523307, 2.85073728, ..., 9.31700178, 1.56390386,
#         0.95367959]),
#  array([1.71266459, 7.92523307, 2.85073728, ..., 9.31700178, 1.56390386,
#         0.95367959]),
#  array([1.71266459, 7.92523307, 2.85073728, ..., 9.31700178, 1.56390386,
#         0.95367959]),
#  array([ 8.53308542,  8.62323403, 12.76582324, ...,  8.51766525,
#          7.78213406, 11.01667069]),
#  array([ 8.53308542,  8.62323403, 12.76582324, ...,  8.51766525,
#          7.78213406, 11.01667069]),
#  array([ 8.53308542,  8.62323403, 12.76582324, ...,  8.51766525,
#          7.78213406, 11.01667069]),
#  array([18.77247477, 16.14526533, 19.89027625, ..., 18.2721131 ,
# ...

# %%
# amps = np.linspace(np.absolute(sv1), np.absolute(sv3), 100)
# phases = np.linspace(cmath.phase(sv1))
state_frames = np.linspace(sv1, sv3, 100)
# np.absolute(state_frames)
[x for x in state_frames]
ok = [[cmath.phase(y) for y in x] for x in state_frames]

phases = np.linspace([cmath.phase(x) for x in sv1], [cmath.phase(x) for x in sv3], 100)

# %%
phases
# Out:
# array([[0.        , 0.        , 0.        , 0.        ],
#        [0.        , 0.        , 0.        , 0.03173326],
#        [0.        , 0.        , 0.        , 0.06346652],
#        [0.        , 0.        , 0.        , 0.09519978],
#        [0.        , 0.        , 0.        , 0.12693304],
#        [0.        , 0.        , 0.        , 0.1586663 ],
#        [0.        , 0.        , 0.        , 0.19039955],
#        [0.        , 0.        , 0.        , 0.22213281],
#        [0.        , 0.        , 0.        , 0.25386607],
#        [0.        , 0.        , 0.        , 0.28559933],
#        [0.        , 0.        , 0.        , 0.31733259],
#        [0.        , 0.        , 0.        , 0.34906585],
#        [0.        , 0.        , 0.        , 0.38079911],
#        [0.        , 0.        , 0.        , 0.41253237],
#        [0.        , 0.        , 0.        , 0.44426563],
#        [0.        , 0.        , 0.        , 0.47599889],
# ...

# %%
def update2(curr):
#     print(amps[curr])
    if curr == 5000:
        a.event_source.stop()
    for i in range(len(ax)):
        ax[i].cla()
        amp = np.absolute(state_frames[curr][i])
        circle = pl.Circle((0, 0), amp, transform=ax[i].transData._b, color="red", alpha=0.6)
        ax[i].add_artist(circle)
        theta = phases[curr][i] + pi/2
        print(theta)
        line, = ax[i].plot([0,theta], [0,1], color='blue')

# %%
import matplotlib.animation as animation
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib notebook
gspec = gridspec.GridSpec(1, 4)
plt.figure()
ax1 = plt.subplot(gspec[0, 0], polar=True)
ax2 = plt.subplot(gspec[0, 1], polar=True)
ax3 = plt.subplot(gspec[0, 2], polar=True)
ax4 = plt.subplot(gspec[0, 3], polar=True)
ax = [ax1, ax2, ax3, ax4] 

gspec.update(wspace = 1, hspace = 1)


fig = plt.gcf()    
a = animation.FuncAnimation(fig, update2, interval = 10, repeat=True)
# print(a)
HTML(a.to_html5_video())
# Out:
# <img src="data:image/png;base64,..." width="432">
# 1.5707963267948966
# 1.5707963267948966
# 1.5707963267948966
# 1.5707963267948966
# 1.5707963267948966
# 1.5707963267948966
# 1.5707963267948966
# 1.5707963267948966
# 1.5707963267948966
# 1.5707963267948966
# 1.5707963267948966
# 1.6025295859220663
# 1.5707963267948966
# 1.5707963267948966
# 1.5707963267948966
# 1.6342628450492358
# 1.5707963267948966
# 1.5707963267948966
# 1.5707963267948966
# 1.6659961041764055
# 1.5707963267948966
# 1.5707963267948966
# 1.5707963267948966
# 1.697729363303575
# 1.5707963267948966
# 1.5707963267948966
# 1.5707963267948966
# 1.7294626224307448
# 1.5707963267948966
# 1.5707963267948966
# 1.5707963267948966
# 1.7611958815579143
# 1.5707963267948966
# 1.5707963267948966
# 1.5707963267948966
# 1.792929140685084
# 1.5707963267948966
# 1.5707963267948966
# 1.5707963267948966
# 1.8246623998122535
# 1.5707963267948966
# 1.5707963267948966
# 1.5707963267948966
# 1.8563956589394233
# 1.5707963267948966
# ...

# %%
gspec.update(wspace = 1, hspace = 1)

# %%
fig = plt.gcf()    
a = animation.FuncAnimation(fig, update, interval = 10)
# Out:
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">
# Traceback (most recent call last):
#   File "/home/djustice/.virtualenvs/CircleNotation-cPkOILQA/lib/python3.6/site-packages/matplotlib/cbook/__init__.py", line 216, in process
#     func(*args, **kwargs)
#   File "/home/djustice/.virtualenvs/CircleNotation-cPkOILQA/lib/python3.6/site-packages/matplotlib/animation.py", line 1465, in _stop
#     self.event_source.remove_callback(self._loop_delay)
# AttributeError: 'NoneType' object has no attribute 'remove_callback'

# %%
amps
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-28420b0bd1b8> in <module>
# ----> 1 amps
#
# NameError: name 'amps' is not defined

# %%
import cmath, math, numpy

cmath.phase(sv3[3])
# Out:
# 3.141592653589793

# %%
cmath.phase(sv2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-83-0de1c5df943b> in <module>
# ----> 1 cmath.phase(sv2)
#
# TypeError: must be real number, not list

# %%
y = np.linspace(1+2j,10+10j,8)
y
# Out:
# array([ 1.         +2.j        ,  2.28571429 +3.14285714j,
#         3.57142857 +4.28571429j,  4.85714286 +5.42857143j,
#         6.14285714 +6.57142857j,  7.42857143 +7.71428571j,
#         8.71428571 +8.85714286j, 10.        +10.j        ])

# %%
np.absolute(1+2j)
# Out:
# 2.23606797749979

# %%
cmath.phase(1+2j)
# Out:
# 1.1071487177940904

# %%
cmath.phase(10+10j)
# Out:
# 0.7853981633974483

# %%
np.linspace(sv1, sv2, 100)
# Out:
# array([[1.        +0.j, 0.        +0.j, 0.        +0.j, 0.        +0.j],
#        [0.99704148+0.j, 0.        +0.j, 0.        +0.j, 0.00714249+0.j],
#        [0.99408297+0.j, 0.        +0.j, 0.        +0.j, 0.01428499+0.j],
#        [0.99112445+0.j, 0.        +0.j, 0.        +0.j, 0.02142748+0.j],
#        [0.98816593+0.j, 0.        +0.j, 0.        +0.j, 0.02856997+0.j],
#        [0.98520741+0.j, 0.        +0.j, 0.        +0.j, 0.03571246+0.j],
#        [0.9822489 +0.j, 0.        +0.j, 0.        +0.j, 0.04285496+0.j],
#        [0.97929038+0.j, 0.        +0.j, 0.        +0.j, 0.04999745+0.j],
#        [0.97633186+0.j, 0.        +0.j, 0.        +0.j, 0.05713994+0.j],
#        [0.97337334+0.j, 0.        +0.j, 0.        +0.j, 0.06428243+0.j],
#        [0.97041483+0.j, 0.        +0.j, 0.        +0.j, 0.07142493+0.j],
#        [0.96745631+0.j, 0.        +0.j, 0.        +0.j, 0.07856742+0.j],
#        [0.96449779+0.j, 0.        +0.j, 0.        +0.j, 0.08570991+0.j],
# ...
